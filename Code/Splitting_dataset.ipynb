# %%
#importing necessary libraries
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
#reading the dataset
df = pd.read_csv("../Data/SF_Crime_data/Police_Department_Incident_Reports__2018_to_Present_20240106.csv")

# %%
df.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2023/03/13 11:41:00 PM    2023/03/13         23:41           2023
# 1  2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 2  2023/03/13 01:16:00 PM    2023/03/13         13:16           2023
# 3  2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 4  2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 0               Monday  2023/03/13 11:41:00 PM  125373607041      1253736
# 1            Wednesday  2023/03/11 03:40:00 PM  125379506374      1253795
# 2               Monday  2023/03/13 01:17:00 PM  125357107041      1253571
# 3               Monday  2023/03/13 11:00:00 AM  125355107041      1253551
# 4              Tuesday  2023/03/14 06:45:00 PM  125402407041      1254024
#
#    Incident Number  CAD Number Report Type Code Report Type Description  \
# ...

# %%
#Splitting the dataframe into 3 chuncks for better handling
[df_1,df_2,df_3,df_4] = np.array_split(df, 4)
# Out:
# d:\Project\Data Engineering\SF-Crime\sf_crime_data_analysis\lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
df_2
# Out:
#              Incident Datetime Incident Date Incident Time  Incident Year  \
# 202823  2022/02/01 07:54:00 AM    2022/02/01         07:54           2022
# 202824  2022/03/31 09:40:00 PM    2022/03/31         21:40           2022
# 202825  2021/02/21 08:00:00 AM    2021/02/21         08:00           2021
# 202826  2022/01/04 03:30:00 PM    2022/01/04         15:30           2022
# 202827  2022/02/07 12:46:00 PM    2022/02/07         12:46           2022
# ...                        ...           ...           ...            ...
# 405641  2018/05/07 05:31:00 PM    2018/05/07         17:31           2018
# 405642  2021/03/16 02:45:00 AM    2021/03/16         02:45           2021
# 405643  2018/02/21 09:00:00 PM    2018/02/21         21:00           2018
# 405644  2021/02/20 11:37:00 PM    2021/02/20         23:37           2021
# 405645  2018/05/01 07:01:00 AM    2018/05/01         07:01           2018
#
#        Incident Day of Week         Report Datetime        Row ID  \
# ...

# %% [markdown]
# ### To join all the parts of the csv files into one dataset, use the below code.

# %%
#joining all the parts of the original dataframe
df_check = pd.concat([df_1,df_2,df_3,df_4])

# %%
df_check.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2023/03/13 11:41:00 PM    2023/03/13         23:41           2023
# 1  2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 2  2023/03/13 01:16:00 PM    2023/03/13         13:16           2023
# 3  2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 4  2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 0               Monday  2023/03/13 11:41:00 PM  125373607041      1253736
# 1            Wednesday  2023/03/11 03:40:00 PM  125379506374      1253795
# 2               Monday  2023/03/13 01:17:00 PM  125357107041      1253571
# 3               Monday  2023/03/13 11:00:00 AM  125355107041      1253551
# 4              Tuesday  2023/03/14 06:45:00 PM  125402407041      1254024
#
#    Incident Number  CAD Number Report Type Code Report Type Description  \
# ...

# %%
#Saving the split dataframe into csv files.
df_1.to_csv(r'../Data/SF_Crime_data/Part_1_Police_Department_Incident_Reports__2018_to_Present.csv')
df_2.to_csv(r'../Data/SF_Crime_data/Part_2_Police_Department_Incident_Reports__2018_to_Present.csv')
df_3.to_csv(r'../Data/SF_Crime_data/Part_3Police_Department_Incident_Reports__2018_to_Present.csv')
df_4.to_csv(r'../Data/SF_Crime_data/Part_4Police_Department_Incident_Reports__2018_to_Present.csv')

# %%
#reading the dataset
df_unemployment = pd.read_csv('../Data/Unemployment_data/Local_Area_Unemployment_Statistics__LAUS_.csv')

# %%
#Splitting the dataframe into 3 chuncks for better handling
[df_1_ue,df_2_ue,df_3_ue] = np.array_split(df, 3)

# %%
df_1_ue.to_csv(r'../Data/Unemployment_data/Part_1_Local_Area_Unemployment_Statistics__LAUS_.csv')
df_2_ue.to_csv(r'../Data/Unemployment_data/Part_2_Local_Area_Unemployment_Statistics__LAUS_.csv')
df_3_ue.to_csv(r'../Data/Unemployment_data/Part_3_Local_Area_Unemployment_Statistics__LAUS_.csv')
